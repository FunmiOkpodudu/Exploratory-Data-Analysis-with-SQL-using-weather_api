# %%
import pandas as pd

# %%
weather_challenge = pd.read_csv('weather_2012.csv')

# %%
weather_challenge.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
weather_challenge.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
weather_challenge.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# ...

# %%
weather_challenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   object
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
weather_challenge['Date/Time'] = pd.to_datetime(weather_challenge['Date/Time'])

# %%
weather_challenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   datetime64[ns]
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
weather_challenge.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# ...

# %% [markdown]
# # Challenge
#
# <b> Find all the unique wind speed value recoreded in the dataset </b>

# %%
weather_challenge['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
weather_challenge['Wind Spd (km/h)'].nunique()
# Out:
# 34

# %% [markdown]
# # To identify unique value and their counts in a colunm

# %%
weather_challenge['Wind Spd (km/h)'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: Wind Spd (km/h), dtype: int64

# %% [markdown]
# # Mini challenge 2
#
# <b> Find the number of times when the weather was exactly clear </b>

# %%
weather_challenge['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
weather_challenge['Weather'].value_counts()[3]  #To get the numbers when the weather was exactly 'clear'
# Out:
# 1326

# %%
weather_challenge['Weather'].value_counts().Clear # To get the last details (freezing rain,snow grains)
# Out:
# 1326

# %%
weather_challenge['Weather'].value_counts()['Clear']
# Out:
# 1326

# %%
weather_challenge['Weather'].value_counts()[12]
# Out:
# 37

# %%
weather_challenge['Weather'].value_counts()[-1]
# Out:
# 1

# %% [markdown]
# # Mini challenge 3

# %%
weather_challenge['Wind Spd (km/h)'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: Wind Spd (km/h), dtype: int64

# %%
weather_challenge['Wind Spd (km/h)'].value_counts()[4]
# Out:
# 474

# %%
weather_challenge.groupby('Wind Spd (km/h)').size() # find number of times when the wind spdw was exactly 4
# Out:
# Wind Spd (km/h)
# 0     309
# 2       2
# 4     474
# 6     609
# 7     677
# 9     830
# 11    791
# 13    735
# 15    719
# 17    666
# 19    616
# 20    496
# 22    439
# 24    374
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 43     13
# 44     14
# 46     11
# 48     13
# 50      4
# 52      7
# 54      1
# 57      5
# 63      1
# 70      1
# 83      1
# dtype: int64

# %%
weather_challenge.groupby('Wind Spd (km/h)').size()
# Out:
# Wind Spd (km/h)
# 0     309
# 2       2
# 4     474
# 6     609
# 7     677
# 9     830
# 11    791
# 13    735
# 15    719
# 17    666
# 19    616
# 20    496
# 22    439
# 24    374
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 43     13
# 44     14
# 46     11
# 48     13
# 50      4
# 52      7
# 54      1
# 57      5
# 63      1
# 70      1
# 83      1
# dtype: int64

# %%
weather_challenge['Wind Spd (km/h)'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: Wind Spd (km/h), dtype: int64

# %%
weather_challenge['Wind Spd (km/h)'].value_counts()[20]
# Out:
# 496

# %% [markdown]
# # Selection
# <b> Part One </b>

# %% [markdown]
# #### How to get the weather column

# %%
col1 = weather_challenge['Weather']

print(type(col1))
col1.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0                     Fog
# 1                     Fog
# 2    Freezing Drizzle,Fog
# 3    Freezing Drizzle,Fog
# 4                     Fog
# Name: Weather, dtype: object

# %% [markdown]
# ### How to get weather and temperature colunm from the dataframe

# %%
two_col1 = weather_challenge[['Weather','Temp (C)']]

print(type(two_col1))
two_col1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 Weather  Temp (C)
# 0                   Fog      -1.8
# 1                   Fog      -1.8
# 2  Freezing Drizzle,Fog      -1.8
# 3  Freezing Drizzle,Fog      -1.5
# 4                   Fog      -1.5

# %% [markdown]
# # To get Weather, Temperature and Rel Humidity

# %%
three_col1 = weather_challenge[['Weather','Temp (C)','Rel Hum (%)']]

print(type(three_col1))
three_col1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 Weather  Temp (C)  Rel Hum (%)
# 0                   Fog      -1.8           86
# 1                   Fog      -1.8           87
# 2  Freezing Drizzle,Fog      -1.8           89
# 3  Freezing Drizzle,Fog      -1.5           88
# 4                   Fog      -1.5           88

# %% [markdown]
# # Getting the first 15 rows

# %%
weather_challenge[:15] #to get the first 15 rows
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9  2012-01-01 09:00:00      -1.3                -3.1           88
# 10 2012-01-01 10:00:00      -1.0                -2.3           91
# 11 2012-01-01 11:00:00      -0.5                -2.1           89
# 12 2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
two_col = weather_challenge[['Date/Time','Visibility (km)']][:15]
two_col
# Out:
#              Date/Time  Visibility (km)
# 0  2012-01-01 00:00:00              8.0
# 1  2012-01-01 01:00:00              8.0
# 2  2012-01-01 02:00:00              4.0
# 3  2012-01-01 03:00:00              4.0
# 4  2012-01-01 04:00:00              4.8
# 5  2012-01-01 05:00:00              6.4
# 6  2012-01-01 06:00:00              6.4
# 7  2012-01-01 07:00:00              8.0
# 8  2012-01-01 08:00:00              8.0
# 9  2012-01-01 09:00:00              4.0
# 10 2012-01-01 10:00:00              1.2
# 11 2012-01-01 11:00:00              4.0
# 12 2012-01-01 12:00:00              4.8
# 13 2012-01-01 13:00:00              4.8
# 14 2012-01-01 14:00:00              4.8

# %%
weather_challenge[['Date/Time','Visibility (km)']][0:10:2]

# %%
result1 = weather_challenge [:6][['Rel Hum (%)', 'Visibility (km)']]

# %%
print(type(result1))
result1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 1           87              8.0
# 2           89              4.0
# 3           88              4.0
# 4           88              4.8

# %%
result2 = weather_challenge[:6:2][['Rel Hum (%)', 'Visibility (km)']]
print(type(result2))
result2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 2           89              4.0
# 4           88              4.8

# %%
result3 = weather_challenge[['Rel Hum (%)', 'Visibility (km)']][:6]
print(type(result3))
result3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 1           87              8.0
# 2           89              4.0
# 3           88              4.0
# 4           88              4.8

# %%
result4 = weather_challenge[['Rel Hum (%)', 'Visibility (km)']][:6:2]
print(type(result4))
result4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 2           89              4.0
# 4           88              4.8

# %%
result1 = weather_challenge[:6][['Rel Hum (%)', 'Visibility (km)']]
result3 = weather_challenge[['Rel Hum (%)', 'Visibility (km)']][:6]

result1 == result3
# Out:
#    Rel Hum (%)  Visibility (km)
# 0         True             True
# 1         True             True
# 2         True             True
# 3         True             True
# 4         True             True
# 5         True             True

# %%
result2 = weather_challenge[:6:2][['Rel Hum (%)', 'Visibility (km)']]
result4 = weather_challenge[['Rel Hum (%)', 'Visibility (km)']][:6:2]

result2 == result4
# Out:
#    Rel Hum (%)  Visibility (km)
# 0         True             True
# 2         True             True
# 4         True             True

# %% [markdown]
# # Mini Challenge 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
output1 = weather_challenge[['Visibility (km)','Rel Hum (%)' ]][:6]

# %%
output1
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 1              8.0           87
# 2              4.0           89
# 3              4.0           88
# 4              4.8           88
# 5              6.4           87

# %%
output2 = weather_challenge[['Visibility (km)','Rel Hum (%)' ]][:6:2]
output2
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 2              4.0           89
# 4              4.8           88

# %% [markdown]
# # Selection
# <b> Part Two </b>

# %%
# using .loc
weather_challenge.loc[0:5, ['Visibility (km)', 'Rel Hum (%)']]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 1              8.0           87
# 2              4.0           89
# 3              4.0           88
# 4              4.8           88
# 5              6.4           87

# %%
weather_challenge[['Visibility (km)', 'Rel Hum (%)']].iloc[0:5]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 1              8.0           87
# 2              4.0           89
# 3              4.0           88
# 4              4.8           88

# %%
output1 = weather_challenge.loc[0:4, ['Visibility (km)', 'Rel Hum (%)']]
output2 = weather_challenge[['Visibility (km)', 'Rel Hum (%)']].iloc[0:5]

output1 == output2
# Out:
#    Visibility (km)  Rel Hum (%)
# 0             True         True
# 1             True         True
# 2             True         True
# 3             True         True
# 4             True         True

# %% [markdown]
# # Using loc for Mini Challenge 4

# %%
weather_challenge.loc[0:4, ['Visibility (km)', 'Rel Hum (%)']]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 1              8.0           87
# 2              4.0           89
# 3              4.0           88
# 4              4.8           88

# %%
weather_challenge.loc[:4:2, ['Visibility (km)', 'Rel Hum (%)']]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 2              4.0           89
# 4              4.8           88

# %%
weather_challenge[['Visibility (km)', 'Rel Hum (%)']].iloc[0:5]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 1              8.0           87
# 2              4.0           89
# 3              4.0           88
# 4              4.8           88

# %%
weather_challenge[['Visibility (km)', 'Rel Hum (%)']].iloc[:5:2]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 2              4.0           89
# 4              4.8           88

# %% [markdown]
# # Filtering

# %%
weather_challenge['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
snowed_filter = weather_challenge['Weather'].str.lower().str.contains('snow')

# %%
snowed_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
weather_challenge[snowed_filter]
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 41   2012-01-02 17:00:00      -2.1                -9.5           57
# 44   2012-01-02 20:00:00      -5.6               -13.4           54
# 45   2012-01-02 21:00:00      -5.8               -12.8           58
# 47   2012-01-02 23:00:00      -7.4               -14.1           59
# 48   2012-01-03 00:00:00      -9.0               -16.0           57
# ...                  ...       ...                 ...          ...
# 8779 2012-12-31 19:00:00       0.1                -2.7           81
# 8780 2012-12-31 20:00:00       0.2                -2.4           83
# 8781 2012-12-31 21:00:00      -0.5                -1.5           93
# 8782 2012-12-31 22:00:00      -0.2                -1.8           89
# 8783 2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 41                 22             25.0            99.66  Snow Showers
# ...

# %%
rain_filter = weather_challenge['Weather'].str.lower().str.contains('rain')

# %%
rain_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
weather_challenge[rain_filter]
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 18   2012-01-01 18:00:00       3.8                 1.0           82
# 19   2012-01-01 19:00:00       3.1                 1.3           88
# 22   2012-01-01 22:00:00       4.4                 1.9           84
# 24   2012-01-02 00:00:00       5.2                 1.5           77
# 153  2012-01-07 09:00:00      -6.1                -8.7           82
# ...                  ...       ...                 ...          ...
# 8537 2012-12-21 17:00:00       1.3                 0.2           92
# 8538 2012-12-21 18:00:00       1.4                 0.3           92
# 8539 2012-12-21 19:00:00       2.3                 1.1           92
# 8540 2012-12-21 20:00:00       2.4                 1.7           95
# 8541 2012-12-21 21:00:00       1.3                 0.4           94
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)            Weather
# 18                 15             12.9            99.74               Rain
# ...

# %%
fog_filter = weather_challenge['Weather'].str.lower().str.contains('fog')

# %%
fog_filter
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
weather_challenge[fog_filter]
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0    2012-01-01 00:00:00      -1.8                -3.9           86
# 1    2012-01-01 01:00:00      -1.8                -3.7           87
# 2    2012-01-01 02:00:00      -1.8                -3.4           89
# 3    2012-01-01 03:00:00      -1.5                -3.2           88
# 4    2012-01-01 04:00:00      -1.5                -3.3           88
# ...                  ...       ...                 ...          ...
# 8739 2012-12-30 03:00:00      -9.1               -10.4           90
# 8740 2012-12-30 04:00:00      -9.3               -10.6           90
# 8741 2012-12-30 05:00:00      -9.1               -10.4           90
# 8742 2012-12-30 06:00:00      -9.3               -10.8           89
# 8770 2012-12-31 10:00:00      -7.4                -8.9           89
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
weather_challenge[weather_challenge['Weather']=='Fog'][:60]
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0    2012-01-01 00:00:00      -1.8                -3.9           86
# 1    2012-01-01 01:00:00      -1.8                -3.7           87
# 4    2012-01-01 04:00:00      -1.5                -3.3           88
# 5    2012-01-01 05:00:00      -1.4                -3.3           87
# 6    2012-01-01 06:00:00      -1.5                -3.1           89
# 7    2012-01-01 07:00:00      -1.4                -3.6           85
# 8    2012-01-01 08:00:00      -1.4                -3.6           85
# 9    2012-01-01 09:00:00      -1.3                -3.1           88
# 10   2012-01-01 10:00:00      -1.0                -2.3           91
# 11   2012-01-01 11:00:00      -0.5                -2.1           89
# 12   2012-01-01 12:00:00      -0.2                -2.0           88
# 13   2012-01-01 13:00:00       0.2                -1.7           87
# 14   2012-01-01 14:00:00       0.8                -1.1           87
# ...
